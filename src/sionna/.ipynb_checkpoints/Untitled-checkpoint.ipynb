# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
import time

# Import Sionna RT components
from sionna.rt import load_scene, Transmitter, Receiver, PlanarArray, Camera, scene

# %%
scene = load_scene(scene.munich) # Try also sionna.rt.scene.etoile

# %%
Camera(position, orientation=(0.,0.,0.), look_at=None)
# Add it to the scene
scene.add(cam)

scene.render(camera=cam, num_samples=512);
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 cam = Camera("my-cam", [0, 0, 50], [0, 0, 0])
#       2 # Add it to the scene
#       3 scene.add(cam)
#
# File ~/ns3-rt/venvrt/lib/python3.10/site-packages/sionna/rt/camera.py:56, in Camera.__init__(self, position, orientation, look_at)
#      54 if look_at is not None:
#      55     if orientation != (0., 0., 0.):
# ---> 56         raise ValueError("Cannot specify both `orientation` and"
#      57                          " `look_at`")
#      59     # Set the position before the look_at so that the camera
#      60     # really points to the target.
#      61     self.position = position
#
# ValueError: Cannot specify both `orientation` and `look_at`
